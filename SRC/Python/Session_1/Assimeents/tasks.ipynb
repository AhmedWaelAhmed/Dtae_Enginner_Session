# %% [markdown]
# Task-1
# Suppose you have this email address “Amit_ml@gmail.edu”
# - Input Validation: Check if the input string contains exactly one "@" symbol and
# at least one "." after the "@" symbol. If it's not a valid email, return "Invalid
# email".
# - Extract Username: Extract and return the part of the email before the "@"
# symbol.
# - Extract Domain: Extract and return the domain (the part between "@" and the
# last ".").
# - Check for Domain Ending: Check if the email ends with ".com". If it does,
# return "Commercial Domain". If it ends with ".edu", return "Educational Domain".
# Otherwise, return "Other Domain".

# %%
email = "Amit_ml@gmail.edu"
if ("@" ,"." in email ):
    print("valid mail")
    print("user name : " ,email[0:7])
    print("domain  : ", email[7:] )
    if(".com" in email):
        print("Commercial Domain")
    elif(".edu" in email):
        print("Educational Domain")
    else:
        print("Other DOMAIN")
else:
    print("invalid try again")
# Out:
# valid mail
# user name :  Amit_ml
# domain  :  @gmail.edu
# Educational Domain

# %% [markdown]
# Task-2:
# Encoded Message:
# ###!!@mocleW EPGTQ!!!6789
# Steps to Decode:
# 1. Extract the core part of the message: "mocleW EPGTQ".
# 2. Reverse the first word: "mocleW" becomes "Welcome".
# 3. Replace shifted vowels in the second word:
# o "EPGTQ": No vowels to change.
# 4. Final decoded message: "Welcome PGTQ".

# %%
message = "###!!@mocleW EPGTQ!!!6789"
mescut= message[6:18]
print(mescut)
therevword= mescut[0:6]

result = therevword[::-1]
print(result)
second_word= mescut[7:12]
print(second_word)
print(result + " " + second_word)
# Out:
# mocleW EPGTQ
# Welcom
# EPGTQ
# Welcom EPGTQ

# %% [markdown]
# Encoded Message:
# &&&**$gnirtS PLIO!!@1234
# Steps to Decode:
# 1. Extract the core part of the message: "gnirtS PLIO".
# 2. Reverse the first word: "gnirtS" becomes "String".
# 3. Replace shifted vowels in the second word:
# o "PLIO": Replace I->E and O->U to get "PLEU".
# 4. Final decoded message: "String PLEU".

# %%
m1 = "&&&**$gnirtS PLIO!!@1234"
m1cut = m1[6:17]
print(m1cut)
revword = m1cut[0:6]
print(revword)
revresult = revword[::-1]
print(revresult)
secondword = m1cut[7:11]
print(secondword)
n =secondword.replace("O", "U")
S= n.replace("I", "E")
print(S)
print(revresult + " " + S)
# Out:
# gnirtS PLIO
# gnirtS
# String
# PLIO
# PLEU
# String PLEU

# %% [markdown]
# Task-4:
# Encoded Message:
# ##$$$@!yalpstcejorp EPUVT****9887
# Steps to Decode:
# 1. Extract the core part of the message: "yalpstcejorp EPUVT".
# 2. Reverse the first word: "yalpstcejorp" becomes "projectplay".
# 3. Replace shifted vowels in the second word:
# o "EPUVT": Replace E->A, U->O to get "APOVT".
# 4. Final decoded message: "projectplay APTOV".

# %%
TExt4 = "##$$$@!yalpstcejorp EPUVT****9887"
TExcut = TExt4[7:25]
print(TExcut)
revo = TExcut[0:12]
print(revo)
revres = revo[::-1] #what we are looking for
print(revres)
replaceword = TExcut[13:18]
a = replaceword.replace("U", "O")
B= a.replace("E", "A") # lasrt word we are looking for
print(revres + " " + B)
# Out:
# yalpstcejorp EPUVT
# yalpstcejorp
# projectsplay
# projectsplay APOVT
